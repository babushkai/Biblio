# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
from tensorflow.python.keras.utils.vis_utils import plot_model
import pydot

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1408        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,370
# Trainable params: 26,370
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 104/104 [==============================] - 2s 8ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 2/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 3/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 4/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 5/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 6/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 7/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 8/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 9/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 10/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 11/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 12/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 13/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 14/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 15/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 16/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 17/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 18/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 19/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 20/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 21/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 22/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 23/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 24/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 25/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 26/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 27/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 28/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 29/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 30/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 31/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 32/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 33/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 34/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 35/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 36/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 37/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 38/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 39/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 40/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 41/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 42/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 43/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 44/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 45/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 46/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 47/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 48/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 49/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 50/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 51/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 52/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 53/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 54/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 55/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 56/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 57/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 58/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 59/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 60/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 61/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 62/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 63/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 64/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 65/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 66/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 67/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 68/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 69/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 70/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 71/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 72/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 73/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 74/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 75/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 76/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 77/500
# 104/104 [==============================] - ETA: 0s - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: n - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 78/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 79/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 80/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 81/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 82/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 83/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 84/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 85/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 86/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 87/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 88/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 89/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 90/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 91/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 92/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 93/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 94/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 95/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 96/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 97/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 98/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 99/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 100/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 101/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 102/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 103/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 104/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 105/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 106/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 107/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 108/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 109/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 110/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 111/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 112/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 113/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 114/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 115/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 116/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 117/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 118/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 119/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 120/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 121/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 122/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 123/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 124/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 125/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 126/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 127/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 128/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 129/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 130/500
# 104/104 [==============================] - 1s 6ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 131/500
# 104/104 [==============================] - 1s 5ms/step - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan - val_loss: nan - val_y1_output_loss: nan - val_y2_output_loss: nan - val_y1_output_root_mean_squared_error: nan - val_y2_output_root_mean_squared_error: nan
# Epoch 132/500
#   1/104 [..............................] - ETA: 0s - loss: nan - y1_output_loss: nan - y2_output_loss: nan - y1_output_root_mean_squared_error: nan - y2_output_root_mean_squared_error: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-834dcbdd1057> in <module>
#       1 # Train the model for 500 epochs
# ----> 2 history = model.fit(norm_train_X, train_Y,
#       3                     epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
