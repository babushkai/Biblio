# %%
import numpy as np
import tensorflow as tf
import keras
from keras import Sequential, Model
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, GlobalAveragePooling2D, MaxPooling2D
from keras.models import Model, load_model
from keras.initializers import glorot_uniform

# %%
class BaseModel:
    def __init__(self, input_shape=(224, 224, 3),factor=1, ):
        inputs = tf.keras.layers.Input(shape=input_shape)
        print(inputs)
        self.factor=1
        self.label_dim = 10
        self.x = inputs
        self.deploy()
        self.factor = factor
        
        self.model = tf.keras.Model(inputs, self.x)
        
    

weight_init = tf.keras.initializers.VarianceScaling()
weight_regularizer = tf.keras.regularizers.l2(l=0.0001)

is_channel_fist = False


class ResNet(BaseModel):
  def __init__(self, *args, **kwargs):
    super(ResNet, self).__init__(*args, **kwargs)

  def get_residual_layer(self):
    n_to_residual = {
        10: [1, 1, 1, 1],
        12: [1, 1, 2, 1],
        14: [1, 2, 2, 1],
        16: [2, 2, 2, 1],
        18: [2, 2, 2, 2],
        20: [2, 2, 3, 2],
        22: [2, 3, 3, 2],
        24: [2, 3, 4, 2],
        26: [2, 3, 5, 2],
        28: [2, 3, 6, 2],
        30: [2, 4, 6, 2],
        32: [3, 4, 6, 2],
        34: [3, 4, 6, 3],
        50: [3, 4, 6, 3],
        101: [3, 4, 23, 3],
        152: [3, 8, 36, 3],
    }
    return n_to_residual[self.res_n]

  def deploy(self):
    if is_channel_fist:
      self.x = tf.transpose(self.x, [0, 3, 1, 2])
      tf.keras.backend.set_image_data_format('channels_first')

    if self.res_n < 50:
      residual_block = self.resblock
    else:
      residual_block = self.bottle_resblock
    residual_list = self.get_residual_layer()
    ch = 64
    self.x = Conv2D(int(ch/self.factor), 7, kernel_initializer=weight_init, kernel_regularizer=weight_regularizer, padding="same", name='conv')(self.x)
    self.x = MaxPooling2D(pool_size=3, strides=2)(self.x)
    for i in range(residual_list[0]):
      residual_block(channels=int(ch/self.factor), downsample=False, block_name='resblock0_' + str(i))
    # block 1
    residual_block(channels=int(ch/self.factor) * 2, downsample=True, block_name='resblock1_0')
    for i in range(1, residual_list[1]):
      residual_block(channels=int(ch/self.factor) * 2, downsample=False, block_name='resblock1_' + str(i))
    # block 2
    residual_block(channels=int(ch/self.factor) * 4, downsample=True, block_name='resblock2_0')
    for i in range(1, residual_list[2]):
      residual_block(channels=int(ch/self.factor) * 4, downsample=False, block_name='resblock2_' + str(i))
    # block 3
    residual_block(channels=int(ch/self.factor) * 8, downsample=True, block_name='resblock_3_0')
    for i in range(1, residual_list[3]):
      residual_block(channels=int(ch/self.factor) * 8, downsample=False, block_name='resblock_3_' + str(i))
    # block 4
    self.x = BatchNormalization(name='batch_norm_last')(self.x)
    self.x = Activation('relu', name='relu_last')(self.x)
    self.x = GlobalAveragePooling2D()(self.x)
    self.x = Dense(units=self.label_dim, kernel_initializer=weight_init, kernel_regularizer=weight_regularizer, use_bias=True,  name='logit')(self.x)

  def resblock(self, channels, use_bias=True, downsample=False, block_name='resblock'):
    x_init = self.x
    self.x = BatchNormalization(name=block_name + '/batch_norm_0')(self.x)
    self.x = Activation('relu', name=block_name + '/relu_0')(self.x)
    if downsample:
      self.x = Conv2D(channels, 3, 2, kernel_initializer=weight_init, kernel_regularizer=weight_regularizer,
                             use_bias=use_bias, padding='same', name=block_name + '/conv_0')(self.x)
      x_init = Conv2D(channels, 1, 2, kernel_initializer=weight_init, kernel_regularizer=weight_regularizer,
                             use_bias=use_bias, padding='same', name=block_name + '/conv_init')(x_init)
    else:
      self.x = Conv2D(channels, 3, 1, kernel_initializer=weight_init, kernel_regularizer=weight_regularizer,
                             use_bias=use_bias, padding='same', name=block_name + '/conv_0')(self.x)
    self.x = BatchNormalization(name=block_name + '/batch_norm_1')(self.x)
    self.x = Activation('relu', name=block_name + '/relu_1')(self.x)
    self.x = Conv2D(channels, 3, 1, kernel_initializer=weight_init, kernel_regularizer=weight_regularizer,
                           use_bias=use_bias, padding='same', name=block_name + '/conv_1')(self.x)
    self.x = Add()([self.x, x_init])

  def bottle_resblock(self, channels, use_bias=True, downsample=False, block_name='bottle_resblock'):
    self.x = BatchNormalization(name=block_name + '/batch_norm_1x1_front')(self.x)
    shortcut = Activation('relu', name=block_name + '/relu_1x1_front')(self.x)
    self.x = Conv2D(channels, 1, 1, 'same', kernel_initializer=weight_init, kernel_regularizer=weight_regularizer,
                           use_bias=use_bias, name=block_name + '/conv_1x1_front')(shortcut)
    self.x = BatchNormalization(name=block_name + '/batch_norm_3x3')(self.x)
    self.x = Activation('relu', name=block_name + '/relu_3x3')(self.x)
    if downsample:
      self.x = Conv2D(channels, 3, 2, 'same', kernel_initializer=weight_init,
                             kernel_regularizer=weight_regularizer, use_bias=use_bias, name=block_name + '/conv_0')(self.x)
      shortcut = Conv2D(channels * 4, 1, 2, 'same', kernel_initializer=weight_init, kernel_regularizer=weight_regularizer,
                               use_bias=use_bias, name=block_name + '/conv_init')(shortcut)
    else:
      self.x = Conv2D(channels, 3, 1, 'same', kernel_initializer=weight_init,
                             kernel_regularizer=weight_regularizer, use_bias=use_bias, name=block_name + '/conv_0')(self.x)
      shortcut = Conv2D(channels * 4, 1, 1, 'same', kernel_initializer=weight_init, kernel_regularizer=weight_regularizer,
                               use_bias=use_bias, name=block_name + '/conv_init')(shortcut)
    self.x = BatchNormalization(name=block_name + '/batch_norm_1x1_back')(self.x)
    self.x = Activation('relu', name=block_name + '/relu_1x1_back')(self.x)
    self.x = Conv2D(channels * 4, 1, 1, 'same', kernel_initializer=weight_init, kernel_regularizer=weight_regularizer,
                           use_bias=use_bias, name=block_name + '/conv_1x1_back')(self.x)
    self.x = Add()([self.x, shortcut])


class ResNetHyper(ResNet):
  def __init__(self, *args, **kwargs):
    super().__init__(*args, **kwargs)

  def model(self):
    self.res_n = 2 * self.hp.Int('depth', min_value=5, max_value=17, step=1)
    super().model()


class ResNet50(ResNet):
  def __init__(self, *args, **kwargs):
    self.res_n = 50
    super().__init__(*args, **kwargs)


class ResNet101(ResNet):
  def __init__(self, *args, **kwargs):
    self.res_n = 101
    super().__init__(*args, **kwargs)
    
class ResNet152(ResNet):
  def __init__(self, *args, **kwargs):
    self.res_n = 152
    super().__init__(*args, **kwargs)

# %%
res = ResNet50(input_shape=(224, 224, 3))
# Out:
# Tensor("input_5:0", shape=(None, 224, 224, 3), dtype=float32)

# %%
res.model.summary()
# Out:
# Model: "functional_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv (Conv2D)                   (None, 224, 224, 64) 9472        input_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 111, 111, 64) 0           conv[0][0]
# __________________________________________________________________________________________________
# resblock0_0/batch_norm_1x1_fron (None, 111, 111, 64) 256         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# resblock0_0/relu_1x1_front (Act (None, 111, 111, 64) 0           resblock0_0/batch_norm_1x1_front[
# __________________________________________________________________________________________________
# resblock0_0/conv_1x1_front (Con (None, 111, 111, 64) 4160        resblock0_0/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock0_0/batch_norm_3x3 (Bat (None, 111, 111, 64) 256         resblock0_0/conv_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock0_0/relu_3x3 (Activatio (None, 111, 111, 64) 0           resblock0_0/batch_norm_3x3[0][0]
# __________________________________________________________________________________________________
# resblock0_0/conv_0 (Conv2D)     (None, 111, 111, 64) 36928       resblock0_0/relu_3x3[0][0]
# __________________________________________________________________________________________________
# resblock0_0/batch_norm_1x1_back (None, 111, 111, 64) 256         resblock0_0/conv_0[0][0]
# __________________________________________________________________________________________________
# resblock0_0/relu_1x1_back (Acti (None, 111, 111, 64) 0           resblock0_0/batch_norm_1x1_back[0
# __________________________________________________________________________________________________
# resblock0_0/conv_1x1_back (Conv (None, 111, 111, 256 16640       resblock0_0/relu_1x1_back[0][0]
# __________________________________________________________________________________________________
# resblock0_0/conv_init (Conv2D)  (None, 111, 111, 256 16640       resblock0_0/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# add_115 (Add)                   (None, 111, 111, 256 0           resblock0_0/conv_1x1_back[0][0]
#                                                                  resblock0_0/conv_init[0][0]
# __________________________________________________________________________________________________
# resblock0_1/batch_norm_1x1_fron (None, 111, 111, 256 1024        add_115[0][0]
# __________________________________________________________________________________________________
# resblock0_1/relu_1x1_front (Act (None, 111, 111, 256 0           resblock0_1/batch_norm_1x1_front[
# __________________________________________________________________________________________________
# resblock0_1/conv_1x1_front (Con (None, 111, 111, 64) 16448       resblock0_1/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock0_1/batch_norm_3x3 (Bat (None, 111, 111, 64) 256         resblock0_1/conv_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock0_1/relu_3x3 (Activatio (None, 111, 111, 64) 0           resblock0_1/batch_norm_3x3[0][0]
# __________________________________________________________________________________________________
# resblock0_1/conv_0 (Conv2D)     (None, 111, 111, 64) 36928       resblock0_1/relu_3x3[0][0]
# __________________________________________________________________________________________________
# resblock0_1/batch_norm_1x1_back (None, 111, 111, 64) 256         resblock0_1/conv_0[0][0]
# __________________________________________________________________________________________________
# resblock0_1/relu_1x1_back (Acti (None, 111, 111, 64) 0           resblock0_1/batch_norm_1x1_back[0
# __________________________________________________________________________________________________
# resblock0_1/conv_1x1_back (Conv (None, 111, 111, 256 16640       resblock0_1/relu_1x1_back[0][0]
# __________________________________________________________________________________________________
# resblock0_1/conv_init (Conv2D)  (None, 111, 111, 256 65792       resblock0_1/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# add_116 (Add)                   (None, 111, 111, 256 0           resblock0_1/conv_1x1_back[0][0]
#                                                                  resblock0_1/conv_init[0][0]
# __________________________________________________________________________________________________
# resblock0_2/batch_norm_1x1_fron (None, 111, 111, 256 1024        add_116[0][0]
# __________________________________________________________________________________________________
# resblock0_2/relu_1x1_front (Act (None, 111, 111, 256 0           resblock0_2/batch_norm_1x1_front[
# __________________________________________________________________________________________________
# resblock0_2/conv_1x1_front (Con (None, 111, 111, 64) 16448       resblock0_2/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock0_2/batch_norm_3x3 (Bat (None, 111, 111, 64) 256         resblock0_2/conv_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock0_2/relu_3x3 (Activatio (None, 111, 111, 64) 0           resblock0_2/batch_norm_3x3[0][0]
# __________________________________________________________________________________________________
# resblock0_2/conv_0 (Conv2D)     (None, 111, 111, 64) 36928       resblock0_2/relu_3x3[0][0]
# __________________________________________________________________________________________________
# resblock0_2/batch_norm_1x1_back (None, 111, 111, 64) 256         resblock0_2/conv_0[0][0]
# __________________________________________________________________________________________________
# resblock0_2/relu_1x1_back (Acti (None, 111, 111, 64) 0           resblock0_2/batch_norm_1x1_back[0
# __________________________________________________________________________________________________
# resblock0_2/conv_1x1_back (Conv (None, 111, 111, 256 16640       resblock0_2/relu_1x1_back[0][0]
# __________________________________________________________________________________________________
# resblock0_2/conv_init (Conv2D)  (None, 111, 111, 256 65792       resblock0_2/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# add_117 (Add)                   (None, 111, 111, 256 0           resblock0_2/conv_1x1_back[0][0]
#                                                                  resblock0_2/conv_init[0][0]
# __________________________________________________________________________________________________
# resblock1_0/batch_norm_1x1_fron (None, 111, 111, 256 1024        add_117[0][0]
# __________________________________________________________________________________________________
# resblock1_0/relu_1x1_front (Act (None, 111, 111, 256 0           resblock1_0/batch_norm_1x1_front[
# __________________________________________________________________________________________________
# resblock1_0/conv_1x1_front (Con (None, 111, 111, 128 32896       resblock1_0/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock1_0/batch_norm_3x3 (Bat (None, 111, 111, 128 512         resblock1_0/conv_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock1_0/relu_3x3 (Activatio (None, 111, 111, 128 0           resblock1_0/batch_norm_3x3[0][0]
# __________________________________________________________________________________________________
# resblock1_0/conv_0 (Conv2D)     (None, 56, 56, 128)  147584      resblock1_0/relu_3x3[0][0]
# __________________________________________________________________________________________________
# resblock1_0/batch_norm_1x1_back (None, 56, 56, 128)  512         resblock1_0/conv_0[0][0]
# __________________________________________________________________________________________________
# resblock1_0/relu_1x1_back (Acti (None, 56, 56, 128)  0           resblock1_0/batch_norm_1x1_back[0
# __________________________________________________________________________________________________
# resblock1_0/conv_1x1_back (Conv (None, 56, 56, 512)  66048       resblock1_0/relu_1x1_back[0][0]
# __________________________________________________________________________________________________
# resblock1_0/conv_init (Conv2D)  (None, 56, 56, 512)  131584      resblock1_0/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# add_118 (Add)                   (None, 56, 56, 512)  0           resblock1_0/conv_1x1_back[0][0]
#                                                                  resblock1_0/conv_init[0][0]
# __________________________________________________________________________________________________
# resblock1_1/batch_norm_1x1_fron (None, 56, 56, 512)  2048        add_118[0][0]
# __________________________________________________________________________________________________
# resblock1_1/relu_1x1_front (Act (None, 56, 56, 512)  0           resblock1_1/batch_norm_1x1_front[
# __________________________________________________________________________________________________
# resblock1_1/conv_1x1_front (Con (None, 56, 56, 128)  65664       resblock1_1/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock1_1/batch_norm_3x3 (Bat (None, 56, 56, 128)  512         resblock1_1/conv_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock1_1/relu_3x3 (Activatio (None, 56, 56, 128)  0           resblock1_1/batch_norm_3x3[0][0]
# __________________________________________________________________________________________________
# resblock1_1/conv_0 (Conv2D)     (None, 56, 56, 128)  147584      resblock1_1/relu_3x3[0][0]
# __________________________________________________________________________________________________
# resblock1_1/batch_norm_1x1_back (None, 56, 56, 128)  512         resblock1_1/conv_0[0][0]
# __________________________________________________________________________________________________
# resblock1_1/relu_1x1_back (Acti (None, 56, 56, 128)  0           resblock1_1/batch_norm_1x1_back[0
# __________________________________________________________________________________________________
# resblock1_1/conv_1x1_back (Conv (None, 56, 56, 512)  66048       resblock1_1/relu_1x1_back[0][0]
# __________________________________________________________________________________________________
# resblock1_1/conv_init (Conv2D)  (None, 56, 56, 512)  262656      resblock1_1/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# add_119 (Add)                   (None, 56, 56, 512)  0           resblock1_1/conv_1x1_back[0][0]
#                                                                  resblock1_1/conv_init[0][0]
# __________________________________________________________________________________________________
# resblock1_2/batch_norm_1x1_fron (None, 56, 56, 512)  2048        add_119[0][0]
# __________________________________________________________________________________________________
# resblock1_2/relu_1x1_front (Act (None, 56, 56, 512)  0           resblock1_2/batch_norm_1x1_front[
# __________________________________________________________________________________________________
# resblock1_2/conv_1x1_front (Con (None, 56, 56, 128)  65664       resblock1_2/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock1_2/batch_norm_3x3 (Bat (None, 56, 56, 128)  512         resblock1_2/conv_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock1_2/relu_3x3 (Activatio (None, 56, 56, 128)  0           resblock1_2/batch_norm_3x3[0][0]
# __________________________________________________________________________________________________
# resblock1_2/conv_0 (Conv2D)     (None, 56, 56, 128)  147584      resblock1_2/relu_3x3[0][0]
# __________________________________________________________________________________________________
# resblock1_2/batch_norm_1x1_back (None, 56, 56, 128)  512         resblock1_2/conv_0[0][0]
# __________________________________________________________________________________________________
# resblock1_2/relu_1x1_back (Acti (None, 56, 56, 128)  0           resblock1_2/batch_norm_1x1_back[0
# __________________________________________________________________________________________________
# resblock1_2/conv_1x1_back (Conv (None, 56, 56, 512)  66048       resblock1_2/relu_1x1_back[0][0]
# __________________________________________________________________________________________________
# resblock1_2/conv_init (Conv2D)  (None, 56, 56, 512)  262656      resblock1_2/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# add_120 (Add)                   (None, 56, 56, 512)  0           resblock1_2/conv_1x1_back[0][0]
#                                                                  resblock1_2/conv_init[0][0]
# __________________________________________________________________________________________________
# resblock1_3/batch_norm_1x1_fron (None, 56, 56, 512)  2048        add_120[0][0]
# __________________________________________________________________________________________________
# resblock1_3/relu_1x1_front (Act (None, 56, 56, 512)  0           resblock1_3/batch_norm_1x1_front[
# __________________________________________________________________________________________________
# resblock1_3/conv_1x1_front (Con (None, 56, 56, 128)  65664       resblock1_3/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock1_3/batch_norm_3x3 (Bat (None, 56, 56, 128)  512         resblock1_3/conv_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock1_3/relu_3x3 (Activatio (None, 56, 56, 128)  0           resblock1_3/batch_norm_3x3[0][0]
# __________________________________________________________________________________________________
# resblock1_3/conv_0 (Conv2D)     (None, 56, 56, 128)  147584      resblock1_3/relu_3x3[0][0]
# __________________________________________________________________________________________________
# resblock1_3/batch_norm_1x1_back (None, 56, 56, 128)  512         resblock1_3/conv_0[0][0]
# __________________________________________________________________________________________________
# resblock1_3/relu_1x1_back (Acti (None, 56, 56, 128)  0           resblock1_3/batch_norm_1x1_back[0
# __________________________________________________________________________________________________
# resblock1_3/conv_1x1_back (Conv (None, 56, 56, 512)  66048       resblock1_3/relu_1x1_back[0][0]
# __________________________________________________________________________________________________
# resblock1_3/conv_init (Conv2D)  (None, 56, 56, 512)  262656      resblock1_3/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# add_121 (Add)                   (None, 56, 56, 512)  0           resblock1_3/conv_1x1_back[0][0]
#                                                                  resblock1_3/conv_init[0][0]
# __________________________________________________________________________________________________
# resblock2_0/batch_norm_1x1_fron (None, 56, 56, 512)  2048        add_121[0][0]
# __________________________________________________________________________________________________
# resblock2_0/relu_1x1_front (Act (None, 56, 56, 512)  0           resblock2_0/batch_norm_1x1_front[
# __________________________________________________________________________________________________
# resblock2_0/conv_1x1_front (Con (None, 56, 56, 256)  131328      resblock2_0/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock2_0/batch_norm_3x3 (Bat (None, 56, 56, 256)  1024        resblock2_0/conv_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock2_0/relu_3x3 (Activatio (None, 56, 56, 256)  0           resblock2_0/batch_norm_3x3[0][0]
# __________________________________________________________________________________________________
# resblock2_0/conv_0 (Conv2D)     (None, 28, 28, 256)  590080      resblock2_0/relu_3x3[0][0]
# __________________________________________________________________________________________________
# resblock2_0/batch_norm_1x1_back (None, 28, 28, 256)  1024        resblock2_0/conv_0[0][0]
# __________________________________________________________________________________________________
# resblock2_0/relu_1x1_back (Acti (None, 28, 28, 256)  0           resblock2_0/batch_norm_1x1_back[0
# __________________________________________________________________________________________________
# resblock2_0/conv_1x1_back (Conv (None, 28, 28, 1024) 263168      resblock2_0/relu_1x1_back[0][0]
# __________________________________________________________________________________________________
# resblock2_0/conv_init (Conv2D)  (None, 28, 28, 1024) 525312      resblock2_0/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# add_122 (Add)                   (None, 28, 28, 1024) 0           resblock2_0/conv_1x1_back[0][0]
#                                                                  resblock2_0/conv_init[0][0]
# __________________________________________________________________________________________________
# resblock2_1/batch_norm_1x1_fron (None, 28, 28, 1024) 4096        add_122[0][0]
# __________________________________________________________________________________________________
# resblock2_1/relu_1x1_front (Act (None, 28, 28, 1024) 0           resblock2_1/batch_norm_1x1_front[
# __________________________________________________________________________________________________
# resblock2_1/conv_1x1_front (Con (None, 28, 28, 256)  262400      resblock2_1/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock2_1/batch_norm_3x3 (Bat (None, 28, 28, 256)  1024        resblock2_1/conv_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock2_1/relu_3x3 (Activatio (None, 28, 28, 256)  0           resblock2_1/batch_norm_3x3[0][0]
# __________________________________________________________________________________________________
# resblock2_1/conv_0 (Conv2D)     (None, 28, 28, 256)  590080      resblock2_1/relu_3x3[0][0]
# __________________________________________________________________________________________________
# resblock2_1/batch_norm_1x1_back (None, 28, 28, 256)  1024        resblock2_1/conv_0[0][0]
# __________________________________________________________________________________________________
# resblock2_1/relu_1x1_back (Acti (None, 28, 28, 256)  0           resblock2_1/batch_norm_1x1_back[0
# __________________________________________________________________________________________________
# resblock2_1/conv_1x1_back (Conv (None, 28, 28, 1024) 263168      resblock2_1/relu_1x1_back[0][0]
# __________________________________________________________________________________________________
# resblock2_1/conv_init (Conv2D)  (None, 28, 28, 1024) 1049600     resblock2_1/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# add_123 (Add)                   (None, 28, 28, 1024) 0           resblock2_1/conv_1x1_back[0][0]
#                                                                  resblock2_1/conv_init[0][0]
# __________________________________________________________________________________________________
# resblock2_2/batch_norm_1x1_fron (None, 28, 28, 1024) 4096        add_123[0][0]
# __________________________________________________________________________________________________
# resblock2_2/relu_1x1_front (Act (None, 28, 28, 1024) 0           resblock2_2/batch_norm_1x1_front[
# __________________________________________________________________________________________________
# resblock2_2/conv_1x1_front (Con (None, 28, 28, 256)  262400      resblock2_2/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock2_2/batch_norm_3x3 (Bat (None, 28, 28, 256)  1024        resblock2_2/conv_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock2_2/relu_3x3 (Activatio (None, 28, 28, 256)  0           resblock2_2/batch_norm_3x3[0][0]
# __________________________________________________________________________________________________
# resblock2_2/conv_0 (Conv2D)     (None, 28, 28, 256)  590080      resblock2_2/relu_3x3[0][0]
# __________________________________________________________________________________________________
# resblock2_2/batch_norm_1x1_back (None, 28, 28, 256)  1024        resblock2_2/conv_0[0][0]
# __________________________________________________________________________________________________
# resblock2_2/relu_1x1_back (Acti (None, 28, 28, 256)  0           resblock2_2/batch_norm_1x1_back[0
# __________________________________________________________________________________________________
# resblock2_2/conv_1x1_back (Conv (None, 28, 28, 1024) 263168      resblock2_2/relu_1x1_back[0][0]
# __________________________________________________________________________________________________
# resblock2_2/conv_init (Conv2D)  (None, 28, 28, 1024) 1049600     resblock2_2/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# add_124 (Add)                   (None, 28, 28, 1024) 0           resblock2_2/conv_1x1_back[0][0]
#                                                                  resblock2_2/conv_init[0][0]
# __________________________________________________________________________________________________
# resblock2_3/batch_norm_1x1_fron (None, 28, 28, 1024) 4096        add_124[0][0]
# __________________________________________________________________________________________________
# resblock2_3/relu_1x1_front (Act (None, 28, 28, 1024) 0           resblock2_3/batch_norm_1x1_front[
# __________________________________________________________________________________________________
# resblock2_3/conv_1x1_front (Con (None, 28, 28, 256)  262400      resblock2_3/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock2_3/batch_norm_3x3 (Bat (None, 28, 28, 256)  1024        resblock2_3/conv_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock2_3/relu_3x3 (Activatio (None, 28, 28, 256)  0           resblock2_3/batch_norm_3x3[0][0]
# __________________________________________________________________________________________________
# resblock2_3/conv_0 (Conv2D)     (None, 28, 28, 256)  590080      resblock2_3/relu_3x3[0][0]
# __________________________________________________________________________________________________
# resblock2_3/batch_norm_1x1_back (None, 28, 28, 256)  1024        resblock2_3/conv_0[0][0]
# __________________________________________________________________________________________________
# resblock2_3/relu_1x1_back (Acti (None, 28, 28, 256)  0           resblock2_3/batch_norm_1x1_back[0
# __________________________________________________________________________________________________
# resblock2_3/conv_1x1_back (Conv (None, 28, 28, 1024) 263168      resblock2_3/relu_1x1_back[0][0]
# __________________________________________________________________________________________________
# resblock2_3/conv_init (Conv2D)  (None, 28, 28, 1024) 1049600     resblock2_3/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# add_125 (Add)                   (None, 28, 28, 1024) 0           resblock2_3/conv_1x1_back[0][0]
#                                                                  resblock2_3/conv_init[0][0]
# __________________________________________________________________________________________________
# resblock2_4/batch_norm_1x1_fron (None, 28, 28, 1024) 4096        add_125[0][0]
# __________________________________________________________________________________________________
# resblock2_4/relu_1x1_front (Act (None, 28, 28, 1024) 0           resblock2_4/batch_norm_1x1_front[
# __________________________________________________________________________________________________
# resblock2_4/conv_1x1_front (Con (None, 28, 28, 256)  262400      resblock2_4/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock2_4/batch_norm_3x3 (Bat (None, 28, 28, 256)  1024        resblock2_4/conv_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock2_4/relu_3x3 (Activatio (None, 28, 28, 256)  0           resblock2_4/batch_norm_3x3[0][0]
# __________________________________________________________________________________________________
# resblock2_4/conv_0 (Conv2D)     (None, 28, 28, 256)  590080      resblock2_4/relu_3x3[0][0]
# __________________________________________________________________________________________________
# resblock2_4/batch_norm_1x1_back (None, 28, 28, 256)  1024        resblock2_4/conv_0[0][0]
# __________________________________________________________________________________________________
# resblock2_4/relu_1x1_back (Acti (None, 28, 28, 256)  0           resblock2_4/batch_norm_1x1_back[0
# __________________________________________________________________________________________________
# resblock2_4/conv_1x1_back (Conv (None, 28, 28, 1024) 263168      resblock2_4/relu_1x1_back[0][0]
# __________________________________________________________________________________________________
# resblock2_4/conv_init (Conv2D)  (None, 28, 28, 1024) 1049600     resblock2_4/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# add_126 (Add)                   (None, 28, 28, 1024) 0           resblock2_4/conv_1x1_back[0][0]
#                                                                  resblock2_4/conv_init[0][0]
# __________________________________________________________________________________________________
# resblock2_5/batch_norm_1x1_fron (None, 28, 28, 1024) 4096        add_126[0][0]
# __________________________________________________________________________________________________
# resblock2_5/relu_1x1_front (Act (None, 28, 28, 1024) 0           resblock2_5/batch_norm_1x1_front[
# __________________________________________________________________________________________________
# resblock2_5/conv_1x1_front (Con (None, 28, 28, 256)  262400      resblock2_5/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock2_5/batch_norm_3x3 (Bat (None, 28, 28, 256)  1024        resblock2_5/conv_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock2_5/relu_3x3 (Activatio (None, 28, 28, 256)  0           resblock2_5/batch_norm_3x3[0][0]
# __________________________________________________________________________________________________
# resblock2_5/conv_0 (Conv2D)     (None, 28, 28, 256)  590080      resblock2_5/relu_3x3[0][0]
# __________________________________________________________________________________________________
# resblock2_5/batch_norm_1x1_back (None, 28, 28, 256)  1024        resblock2_5/conv_0[0][0]
# __________________________________________________________________________________________________
# resblock2_5/relu_1x1_back (Acti (None, 28, 28, 256)  0           resblock2_5/batch_norm_1x1_back[0
# __________________________________________________________________________________________________
# resblock2_5/conv_1x1_back (Conv (None, 28, 28, 1024) 263168      resblock2_5/relu_1x1_back[0][0]
# __________________________________________________________________________________________________
# resblock2_5/conv_init (Conv2D)  (None, 28, 28, 1024) 1049600     resblock2_5/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# add_127 (Add)                   (None, 28, 28, 1024) 0           resblock2_5/conv_1x1_back[0][0]
#                                                                  resblock2_5/conv_init[0][0]
# __________________________________________________________________________________________________
# resblock_3_0/batch_norm_1x1_fro (None, 28, 28, 1024) 4096        add_127[0][0]
# __________________________________________________________________________________________________
# resblock_3_0/relu_1x1_front (Ac (None, 28, 28, 1024) 0           resblock_3_0/batch_norm_1x1_front
# __________________________________________________________________________________________________
# resblock_3_0/conv_1x1_front (Co (None, 28, 28, 512)  524800      resblock_3_0/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock_3_0/batch_norm_3x3 (Ba (None, 28, 28, 512)  2048        resblock_3_0/conv_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock_3_0/relu_3x3 (Activati (None, 28, 28, 512)  0           resblock_3_0/batch_norm_3x3[0][0]
# __________________________________________________________________________________________________
# resblock_3_0/conv_0 (Conv2D)    (None, 14, 14, 512)  2359808     resblock_3_0/relu_3x3[0][0]
# __________________________________________________________________________________________________
# resblock_3_0/batch_norm_1x1_bac (None, 14, 14, 512)  2048        resblock_3_0/conv_0[0][0]
# __________________________________________________________________________________________________
# resblock_3_0/relu_1x1_back (Act (None, 14, 14, 512)  0           resblock_3_0/batch_norm_1x1_back[
# __________________________________________________________________________________________________
# resblock_3_0/conv_1x1_back (Con (None, 14, 14, 2048) 1050624     resblock_3_0/relu_1x1_back[0][0]
# __________________________________________________________________________________________________
# resblock_3_0/conv_init (Conv2D) (None, 14, 14, 2048) 2099200     resblock_3_0/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# add_128 (Add)                   (None, 14, 14, 2048) 0           resblock_3_0/conv_1x1_back[0][0]
#                                                                  resblock_3_0/conv_init[0][0]
# __________________________________________________________________________________________________
# resblock_3_1/batch_norm_1x1_fro (None, 14, 14, 2048) 8192        add_128[0][0]
# __________________________________________________________________________________________________
# resblock_3_1/relu_1x1_front (Ac (None, 14, 14, 2048) 0           resblock_3_1/batch_norm_1x1_front
# __________________________________________________________________________________________________
# resblock_3_1/conv_1x1_front (Co (None, 14, 14, 512)  1049088     resblock_3_1/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock_3_1/batch_norm_3x3 (Ba (None, 14, 14, 512)  2048        resblock_3_1/conv_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock_3_1/relu_3x3 (Activati (None, 14, 14, 512)  0           resblock_3_1/batch_norm_3x3[0][0]
# __________________________________________________________________________________________________
# resblock_3_1/conv_0 (Conv2D)    (None, 14, 14, 512)  2359808     resblock_3_1/relu_3x3[0][0]
# __________________________________________________________________________________________________
# resblock_3_1/batch_norm_1x1_bac (None, 14, 14, 512)  2048        resblock_3_1/conv_0[0][0]
# __________________________________________________________________________________________________
# resblock_3_1/relu_1x1_back (Act (None, 14, 14, 512)  0           resblock_3_1/batch_norm_1x1_back[
# __________________________________________________________________________________________________
# resblock_3_1/conv_1x1_back (Con (None, 14, 14, 2048) 1050624     resblock_3_1/relu_1x1_back[0][0]
# __________________________________________________________________________________________________
# resblock_3_1/conv_init (Conv2D) (None, 14, 14, 2048) 4196352     resblock_3_1/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# add_129 (Add)                   (None, 14, 14, 2048) 0           resblock_3_1/conv_1x1_back[0][0]
#                                                                  resblock_3_1/conv_init[0][0]
# __________________________________________________________________________________________________
# resblock_3_2/batch_norm_1x1_fro (None, 14, 14, 2048) 8192        add_129[0][0]
# __________________________________________________________________________________________________
# resblock_3_2/relu_1x1_front (Ac (None, 14, 14, 2048) 0           resblock_3_2/batch_norm_1x1_front
# __________________________________________________________________________________________________
# resblock_3_2/conv_1x1_front (Co (None, 14, 14, 512)  1049088     resblock_3_2/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock_3_2/batch_norm_3x3 (Ba (None, 14, 14, 512)  2048        resblock_3_2/conv_1x1_front[0][0]
# __________________________________________________________________________________________________
# resblock_3_2/relu_3x3 (Activati (None, 14, 14, 512)  0           resblock_3_2/batch_norm_3x3[0][0]
# __________________________________________________________________________________________________
# resblock_3_2/conv_0 (Conv2D)    (None, 14, 14, 512)  2359808     resblock_3_2/relu_3x3[0][0]
# __________________________________________________________________________________________________
# resblock_3_2/batch_norm_1x1_bac (None, 14, 14, 512)  2048        resblock_3_2/conv_0[0][0]
# __________________________________________________________________________________________________
# resblock_3_2/relu_1x1_back (Act (None, 14, 14, 512)  0           resblock_3_2/batch_norm_1x1_back[
# __________________________________________________________________________________________________
# resblock_3_2/conv_1x1_back (Con (None, 14, 14, 2048) 1050624     resblock_3_2/relu_1x1_back[0][0]
# __________________________________________________________________________________________________
# resblock_3_2/conv_init (Conv2D) (None, 14, 14, 2048) 4196352     resblock_3_2/relu_1x1_front[0][0]
# __________________________________________________________________________________________________
# add_130 (Add)                   (None, 14, 14, 2048) 0           resblock_3_2/conv_1x1_back[0][0]
#                                                                  resblock_3_2/conv_init[0][0]
# __________________________________________________________________________________________________
# batch_norm_last (BatchNormaliza (None, 14, 14, 2048) 8192        add_130[0][0]
# __________________________________________________________________________________________________
# relu_last (Activation)          (None, 14, 14, 2048) 0           batch_norm_last[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 2048)         0           relu_last[0][0]
# __________________________________________________________________________________________________
# logit (Dense)                   (None, 10)           20490       global_average_pooling2d_4[0][0]
# ==================================================================================================
# Total params: 38,153,098
# Trainable params: 38,107,658
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(res.model)
